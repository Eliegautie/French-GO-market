# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Elie\Desktop\Go\Auction.csv')
df_1 = pd.read_csv(r'C:\Users\Elie\Desktop\Go\temp_moyenne.csv')

# %%
del df_1['Unnamed: 0'] 
df_1.set_index('Mois')
# Out:
#             2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# Mois
# janvier     8.05   9.76   9.59   9.48  10.74  10.07   9.46   7.89  11.65
# février     9.65  10.89   7.13   8.64  10.44   9.43   9.69  11.27   8.30
# mars       11.13  12.24  12.72  10.86  12.10  10.86  10.40  12.95  10.97
# avril      14.42  15.85  12.76  13.30  14.70  13.40  12.80  13.73  14.13
# mai        15.40  17.16  16.28  14.31  15.46  15.45  15.59  16.92  16.09
# juin       18.46  18.25  18.29  17.46  18.67  18.67  18.25  19.99  19.04
# juillet    20.65  18.45  19.63  20.96  20.83  20.83  20.22  20.73  21.45
# août       19.19  19.74  21.23  19.92  19.84  19.84  20.61  20.76  21.42
# septembre  16.88  18.82  18.04  17.95  15.95  15.95  19.25  16.94  19.20
# octobre    14.73  15.52  15.52  16.21  13.22  13.22  14.60  15.95  16.08
# novembre   11.81  13.40  12.40  11.39  12.24  12.24  12.48  11.66  12.90
# décembre    8.34  11.18  10.84  10.06  11.18  11.18  10.02  10.02  11.75
#
# ...

# %%
df
# Out:
#          Mois  Volume total moyen vendu 2019  \
# 0     January                            NaN
# 1    February                            NaN
# 2       March                       69049.69
# 3       April                       41429.36
# 4         May                       43027.53
# 5        June                       37495.61
# 6        July                       33228.89
# 7      August                       30683.64
# 8   September                       41523.00
# 9     October                       25678.77
# 10   November                       25254.41
# 11   December                       14064.18
#
#     Prix moyen pondéré 2019 (€ / MWh)  Volume total moyen vendu 2020  \
# 0                                 NaN                      60244.139
# 1                                 NaN                      82006.833
# 2                               0.303                      36138.660
# 3                               0.731                      41960.710
# ...

# %%
temp_2019 = df_1[df_1.columns[10]][2:].to_list()
temp_2020 = df_1[df_1.columns[11]].to_list()
temp_2021 = df_1[df_1.columns[12]].to_list()
temp_2022 = df_1[df_1.columns[13]].to_list()
temp_2023 = df_1[df_1.columns[14]][:5].to_list()

prix_2019 = df[df.columns[2]][2:].to_list()
prix_2020 = df[df.columns[4]].to_list()
prix_2021 = df[df.columns[6]].to_list()
prix_2022 = df[df.columns[8]].to_list()
prix_2023 = df[df.columns[10]][:5].to_list()

# %%
temp = temp_2019 + temp_2020 + temp_2021 + temp_2022 + temp_2023
prix = prix_2019 + prix_2020 + prix_2021 + prix_2022 + prix_2023

# %%
plt.plot(temp)

# %%
plt.plot(prix)

# %% [markdown]
# **Etude année 2019-2020**

# %%
temp_2019 = temp_2019 + temp_2020 
prix_2019 = prix_2019 + prix_2020

# %%
plt.plot(temp_2019)

# %%
plt.plot(prix_2019)
